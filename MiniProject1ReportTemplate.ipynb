# %% [markdown]
# # Mini Project 1 Report

# %% [markdown]
# Your name: `Jack Rogers`

# %%
# %matplotlib inline
import math 
from curveFitting import one_dimensional_curve_fitting_test

# %% [markdown]
# ## Benchmarking

# %% [markdown]
# - Attempt these problems only after you have finished and tested your implementation.
# - If you modify any of the python files, remember to "restart the kernel" or else the changes will not take effect.
# - We have provided 5 tests below. For each test, run it 5 different times and record the best solution/fitness for each trial along with the run time.
# - You will need to modify the code below, perhaps adding some nice print statements or adding your results to a table.

# %%
one_dimensional_curve_fitting_test(lambda x: 0.2*math.exp(x/4.0) -  math.sin(2*x)  , (-10.0, 10.0), 25)
# Out:
# Generation:  0
# Generation:  10
# Generation:  20
# Generation:  30
# Generation:  40
# Generation:  50
# Generation:  60
# Generation:  70
# Generation:  80
# Generation:  90
# Run Time: 38.26337003707886
# GA Returned Solution: cos((sin(x) + cos(x))) with fitness -7.051541182590415

# %%
one_dimensional_curve_fitting_test(lambda x: math.sin(2*x) - math.cos(3*x-1) + 2*math.sin(x/2+1.0)  , (-15.0, 15.0), 60)
# Out:
# Generation:  0
# Generation:  10
# Generation:  20
# Generation:  30
# Generation:  40
# Generation:  50
# Generation:  60
# Generation:  70
# Generation:  80
# Generation:  90
# Run Time: 63.97852849960327
# GA Returned Solution: (cos((x/2.0))/cos(cos((x/(cos((x/2.0))/0.5))))) with fitness -54.616714189666

# %%
one_dimensional_curve_fitting_test(lambda x: math.exp(math.sin(2*x)) - math.exp(math.cos(3*x))  , (-15.0, 15.0), 60)
# Out:
# Generation:  0
# Generation:  10
# Generation:  20
# Generation:  30
# Generation:  40
# Generation:  50
# Generation:  60
# Generation:  70
# Generation:  80
# Generation:  90
# Run Time: 59.552446603775024
# GA Returned Solution: sinh(sinh(sin((x + x) - cos(x)))) with fitness -21.818886753847092

# %%
one_dimensional_curve_fitting_test(lambda x: 0.05*x**2 - 0.5*x + 5.0 * math.sin(3*x) , (-15.0, 15.0), 60)
# Out:
# Generation:  0
# Generation:  10
# Generation:  20
# Generation:  30
# Generation:  40
# Generation:  50
# Generation:  60
# Generation:  70
# Generation:  80
# Generation:  90
# Run Time: 122.45447993278503
# GA Returned Solution: (((atan((x + x)) - -1.0 * (x + -2.0))/exp(atan((x + x)) - -1.0)) + cos((x - 1.0 - 1.0 + (x + x)))) with fitness -530.7860901272421

# %%
one_dimensional_curve_fitting_test(lambda x: 0.05*x**2 - 0.5*math.sqrt(x) + 5.0 * math.sin(3*x) , (0.0, 15.0), 30)
# Out:
# Generation:  0
# Generation:  10
# Generation:  20
# Generation:  30
# Generation:  40
# Generation:  50
# Generation:  60
# Generation:  70
# Generation:  80
# Generation:  90
# Run Time: 93.15747141838074
# GA Returned Solution: (((x/7.38905609893065) + sin((x + x + x))) * exp(cosh(tanh(sin(sin((x + x + x))))))) with fitness -76.89951724782799

# %% [markdown]
# `Put your table with results here!` You may [create a table using markdown](https://www.tablesgenerator.com/markdown_tables) (below) or print a nicely formatted table using a library such as Pandas.
#
# Test 1:
#
# | Trial | Best Fitness | Best Solution | Run Time (Seconds) |
# |-|-|-|-|
# | 1 | -9.587 | (x - cos(x) - -2.0/8.558541242841308) | 43.173 |
# | 2 | -5.753 | sin(sin((x * -2.0))) - ((x - 2.0 + (x * x * -0.5) + 0.8775825618903728) + (x * x * 0.5) - x - 0.5) | 38.982 |
# | 3 | -10.389 | atan((exp((exp(x - 2.0)/x - -0.5) - 2.0)/(2.5))) | 68.740 |
# | 4 | -11.921 | sinh((x - -2.0/8.26425316026166)) | 40.255 |
# | 5 | -7.052 | cos((sin(x) + cos(x))) | 38.263 |
#
# Test 2:
#
# | Trial | Best Fitness | Best Solution | Run Time (Seconds) |
# |-|-|-|-|
# | 1 | -56.680 | (cos(((x + -0.5390427263595186) + (x/-2.0))) + sinh(cos(((x + -0.5) + (x/-2.0))))) | 90.600 |
# | 2 | -57.960 | (sinh(sin((x * 0.5) - x - 8.23292865714615))/cos(tanh((x + x + x)))) | 126.073 |
# | 3 | -58.847 | (sinh(cos((x * 0.5) - 0.6931471805599453))/0.6390124941652592) | 65.652 |
# | 4 | -76.584 | ((((x + x) + (x + x + x + -5.57650554901949) + x)/(x + x + x + -2.0) - ((x + -1.0) * 0.5403023058681398)) * cos(((x + -1.0) * 0.5403023058681398))) | 96.840 |
# | 5 | -54.617 | (cos((x/2.0))/cos(cos((x/(cos((x/2.0))/0.5))))) | 63.979 |
#
# Test 3:
#
# | Trial | Best Fitness | Best Solution | Run Time (Seconds) |
# |-|-|-|-|
# | 1 | -20.326 | sinh(sinh(sin((x * 2.0) - cos(x)))) | 69.702 |
# | 2 | -26.981 | sinh(sinh(sin((x + x) - cos(x)))) | 63.969 |
# | 3 | -3.986 | (sin((x + x + x + 4.630402733523532)) + sin((x * 2.0))) | 68.317 |
# | 4 | -9.929 | (sinh(sin((x + x) - cos(x))) + sin((sin((x + x) - cos((x + x))) + (x + x + x + -1.0)))) | 120.748 |
# | 5 | -21.819 | sinh(sinh(sin((x + x) - cos(x)))) | 59.552 |
#
# Test 4:
#
# | Trial | Best Fitness | Best Solution | Run Time (Seconds) |
# |-|-|-|-|
# | 1 | -201.497 | ((((cosh(((((x + -0.5) + -1.0)/5.9944241228046735) + -1.0)) + cos(((x + -0.5) + (x + x + -1.0)))) + cos(((x + -0.5) + (x + x + -1.0)))) + cos(((x + -0.5) + (x + x + -1.0)))) + cos(((x + -0.5) + (x + x + -1.0)))) | 164.376 |
# | 2 | -668.707 | exp((x/-4.794391044697301)) - cos(((x * x * x * 1.0) * ((x - 1.0 + (x/-4.794391044697301))/-4.794391044697301))) - sin((x - 1.0 + (x - 1.0/-4.794391044697301))) | 103.297 |
# | 3 | -670.126 | (sqrt(exp(((x * -0.5)/1.1276259652063807))) * 0.8775825618903728) - sin(cos(((sqrt(exp(((x * -0.5)/1.1276259652063807))) * cos(cos(x))) * -0.5))) | 211.644 |
# | 4 | -771.571 | (-1.0/(((1.0)/x - -1.0 - -1.0) + exp((((((x - -1.0 + -1.0) + -1.0)/3.172386072891154) + -1.0) + ((((x + -1.0) + -1.0)/3.172386072891154) + -1.0))))) | 105.967 |
# | 5 | -530.786 | (((atan((x + x)) - -1.0 * (x + -2.0))/exp(atan((x + x)) - -1.0)) + cos((x - 1.0 - 1.0 + (x + x)))) | 122.454 |
#
# Test 5:
#
# | Trial | Best Fitness | Best Solution | Run Time (Seconds) |
# |-|-|-|-|
# | 1 | -52.873 | (((((((x * 0.5)/2.0) + cos((x + x + x + -1.5))) + cos((x + x + x + -1.5))) + -0.4161468365471424) + cos((x + x + x + -1.5)))/cos(tanh((x + x + x + -1.5)))) | 145.294 |
# | 2 | -105.864 | (((((x/2.122176356183976) + -1.0) + sin(((x + x)/0.6931471805599453))) * exp(sin(sin(sin(sin((x + x + x))))))) + sin((x + x + x))) | 106.702 |
# | 3 | -259.625 | (((x + -0.5) - (((x + -4.389979490072187) + -2.0)/x - -8.86701635049888) + -3.0) * tanh(atan(x))) - tanh(((x + -0.5) * cos((x + -0.5)) * 7.38905609893065)) | 94.070 |
# | 4 | -329.553 | ((x + -5.462025468607774) * sin(((x + x + -2.0)/x - -5.462025468607774))) - sin((sin((sin((x - -0.5/0.7853981633974483))/0.7853981633974483)) - -0.5/0.7853981633974483)) | 67.719 |
# | 5 | -76.900 | (((x/7.38905609893065) + sin((x + x + x))) * exp(cosh(tanh(sin(sin((x + x + x))))))) | 93.157 |

# %% [markdown]
# Write a brief analysis of your results. Some questions to answer:
# - Which problem ran the fastest? Why do you think this is the case?
# - Which problem ended with the highest fitness? Why do you think this is the case?
# - How similar were the running times across the 5 repetitions?
# - How similar were the final fitness scores across the 5 repetitions?
# - Was there anything else interesting in your results?

# %% [markdown]
# - The first problem ran the fastest on average and I think this is the case because the function being modeled in this case appears to be more simple than the following tests.
# - The first problem had the highest fitness on average and I think this is because the algorithm has an easier time finding simple mutations for simpler functions. Interestingly, the highest fitness trial occured in trial 3 of Test 3, which yielded a fitness of -3.986.
# - The running times were relatively similar across the 5 repetitions, but some trials definitely took longer than others.
# - The final fitness scores for each test were relatively similar as well, but there was some variation. For example, trial 1 of Test 5 yielded a fitness of -52.873 while trial 4 yielded -329.553.
# - Test 5 was interesting because sometimes it would produce results in under two minutes but other times, it would appear to get stuck and I would have to restart it. There appears to be some amount of luck involved in the sense that depending on the initial population or how well the random mutations fit, there will be a certain best fitness.

# %% [markdown]
# ## Describe Your Implementation and Reflect

# %% [markdown]
# Some questions to answer in your write-up:
# - What was your strategy to solve this problem?
# - How did you structure your `GASolver` class?
# - What other files or methods did you change?
# - What was the most difficult part of the project?
# - What was something surprising you found?
#
# Please provide some elaboration with your answers. When describing your implementation, remember that we have not watched you solve this problem so you will need to give more details than you think is necessary.

# %% [markdown]
# - My strategy to solve this problem involved getting completely familiar with the write up first. Then, I focused on creating a function to establish an initial random population. I took this project step by step while only working on getting one iteration working. After I proved that one iteration worked, I then added the looping involved with iterating.
# - The only adjustments to the GASolver class were that I made self.pop a dictionary and created a seperate initial population function.
# - I made no other changes.
# - The most difficult part of the project was probably the initial understanding of what our task was. After I was familiar with what to do, the next challenge was keeping track of details, such as loops and copies of variables.
# - Something surprising that I found was how slow my program ran at first. After discovering that I was calling the fitness function way too many times in a loop, I increased my speed so I could actually run test 4 and 5. I also was surprised to see how well the algorithm modeled the functions, specifically trial 3 of Test 3.

# %% [markdown]
# ## Going Above and Beyond

# %% [markdown]
# Describe the extra changes you implemented. Give some details, perhaps a short paragraph for each major change.

# %% [markdown]
# `Your answer here.`

# %% [markdown]
# Describe the analysis you did and provide your results in the form of a figure or a table.

# %% [markdown]
# `Your answer here.`

# %% [markdown]
# Reflect on your work for this section. What was interesting, or what did you learn? A short paragraph here is fine.

# %% [markdown]
# `Your answer here.`
